# %% [markdown]
# ## Simple Linear Regression Lab
#
# # Objectives
# After completing this lab you will be able to:
#
# * Use scikit-learn to implement simple Linear Regression
# * Create a model, train it, test it and use the model

# %% [markdown]
# * Playing with data and Ploting some features

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\Fuel Consumption Ratings.csv", encoding = 'latin-1')

'Taking a look at the data'
# df.head()

'Describing data'
# df.describe()

'Selecting some features'
cdf = df[['Engine_Size', 'CO2_Emissions', 'CO2']]

# cdf.head(10)


"Ploting some features"

viz = cdf[['Engine_Size', 'CO2_Emissions', 'CO2']]
# viz.hist()

"""
Drawing a scatter plot:
1. Engine Size Vs Emission of CO2
2. Engine Size Vs Consommation of Carburant

"""

plt.scatter(cdf.Engine_Size, cdf.CO2_Emissions, color = 'blue')
plt.xlabel('Engine Size')
plt.ylabel('CO2_Emissions')
plt.show()

# %% [markdown]
#  # Traing Linear regression Model
#
#  * Lets split our dataset into train and test sets,80% of the entire data for training, and the 20% for testing.
# * We create a mask to select random rows using np.random.rand() function:

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt


df = pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\Fuel Consumption Ratings.csv", encoding = 'latin-1')

'Selecting some features'
cdf = df[['Engine_Size','Cylinders', 'CO2_Emissions', 'CO2']]

'Splitting dataset into train and test sets: 80% data for training and 20% for testing'
msk = np.random.rand(len(df)) < 0.8   #it creates an array of Boleans True and False of the length of data set
train = cdf[msk]
test = cdf[~msk]



'Ploting traing data'
plt.scatter(train.Engine_Size, train.CO2_Emissions, color = 'blue')
plt.xlabel('Engine Size')
plt.ylabel('Emissions of CO2')

'Training the model'
regr = linear_model.LinearRegression()

train_x = np.asanyarray(train[['Engine_Size']])
train_y = np.asanyarray(train[['CO2_Emissions']])


regr.fit(train_x, train_y)

'Now we plot our output as  line'
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')

print('Coefficients: ', regr.coef_)
print('Intercepts: ', regr.intercept_)
plt.show()
# Out:
# Coefficients:  [[36.71279258]]
# Intercepts:  [139.83194957]

# %% [markdown]
# # Excercise
# * Finding a linear model for Engine Size and Fuel_Consumption

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

df = pd.read_csv('C:\\Users\\LENOVO\\OneDrive\\Desktop\\Fuel Consumption Ratings.csv', encoding = 'latin-1')
cdf = df[['Model', 'Make', 'Engine_Size', 'Cylinders', 'Fuel_Consumption', 'CO2_Emissions', 'Smog']]


msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

regr = linear_model.LinearRegression()

train_x = np.asanyarray(train[['Engine_Size']])
train_y = np.asanyarray(train[['Fuel_Consumption']])

regr.fit(train_x, train_y)
plt.scatter(cdf.Engine_Size, cdf.Fuel_Consumption, color = 'blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel('Engine Size')
plt.ylabel('Fuel Comumption')

print('Coefficients:', regr.coef_)
print('Intercepts:', regr.intercept_)

plt.show()
# Out:
# Coefficients: [[2.14672322]]
# Intercepts: [5.66664949]

# %% [markdown]
# # Evaluation
#
# * R-squared is not an error, but rather a popular metric to measure the performance of your regression model. It represents how close the data points are to the fitted regression line.
# * The higher the R-squared value, the better the model fits your data.
# * The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse)."""

# %%
from sklearn.metrics import r2_score
from sklearn import linear_model
import numpy as np
import pandas as pd

df = pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\Fuel Consumption Ratings.csv", encoding ='latin-1')
cdf = df[['Engine_Size','Cylinders', 'CO2_Emissions', 'CO2']]

msk = np.random.rand(len(df)) > 0.8
train = df[msk]
test = df[~msk]

regr = linear_model.LinearRegression()
test_x = np.asanyarray(test[['Engine_Size']])
test_y = np.asanyarray(test[['Fuel_Consumption']])

regr.fit(test_x, test_y)

test_y_ = regr.predict(test_x)

print("Mean Absolute Error: %0.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Mean Squared Ab error: %0.2f" % np.mean(np.absolute(test_y_ - test_y)**2))
print("R2-Score : %0.2r"% r2_score(test_y, test_y_))
# Out:
# Mean Absolute Error: 1.50
# Mean Squared Ab error: 3.80
# R2-Score : 0.
